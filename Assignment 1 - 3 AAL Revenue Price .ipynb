# %%
import matplotlib.pyplot as plt
import numpy as np
import datetime
# %matplotlib inline
data = pd.read_excel("C:\\Users\\srava\\OneDrive\\Desktop\\AAL Revenue.xlsx")
data
# Out:
#          Date  Quarterly Revenue(in Billions)
# 0  2022-06-30                           13422
# 1  2022-03-31                            8896
# 2  2021-12-31                            9427
# 3  2021-09-30                            8969
# 4  2021-06-30                            7478
# 5  2021-03-31                            4008
# 6  2020-12-31                            4027
# 7  2020-09-30                            3173
# 8  2020-06-30                            1622
# 9  2020-03-31                            8515
# 10 2019-12-31                           11313
# 11 2019-09-30                           11911
# 12 2019-06-30                           11960
# 13 2019-03-31                           10584
# 14 2018-12-31                           10938
# 15 2018-09-30                           11559
# 16 2018-06-30                           11643
# 17 2018-03-31                           10401
# 18 2017-12-31                           10610
# ...

# %%
# %matplotlib notebook
plot= data.plot.line(x='Date')
# Out:
# <img src="data:image/png;base64,..." width="432">
