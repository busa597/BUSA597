# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import datetime
# %matplotlib inline
data = pd.read_csv("C:\\Users\\srava\\Downloads\\AAL.csv",header=0,index_col =0)
data
# Out:
#                Open       High    Low      Close  Adj Close    Volume
# Date
# 6/1/2022  18.070000  18.100000  16.98  17.290001  17.290001  32637900
# 6/2/2022  17.270000  17.510000  17.18  17.459999  17.459999  23337700
# 6/3/2022  17.000000  17.049999  16.09  16.219999  16.219999  46267600
# 6/6/2022  16.530001  16.570000  16.02  16.299999  16.299999  29567800
# 6/7/2022  16.100000  16.730000  15.96  16.690001  16.690001  29278100
# ...             ...        ...    ...        ...        ...       ...
# 8/1/2022  14.170000  14.460000  14.09  14.420000  14.420000  22167800
# 8/2/2022  14.410000  14.540000  13.71  13.740000  13.740000  23133100
# 8/3/2022  13.510000  13.710000  13.45  13.510000  13.510000  21391200
# 8/4/2022  13.610000  13.680000  13.20  13.330000  13.330000  25076800
# 8/5/2022  13.490000  13.530000  12.96  12.990000  12.990000  27923800
#
# [64 rows x 6 columns]

# %%
# %matplotlib notebook
data['Open'].plot(label='opening of stocks')
data['Close'].plot(label='closing of stocks')
data['High'].plot(label='High')
data['Low'].plot(label='Low')
data['Adj Close'].plot(label='Adjusted Closing Price')
plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="916">
